# %% [markdown]
# <a href="https://colab.research.google.com/github/robert-pineau/CIND-860-Capstone/blob/main/CIND860_TL_VGG19_full_augment_mlo_only_evaluate_only.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CIND860: W24: Advanced Data Analytics Project
# Robert M. Pineau
# 941-049-371

# %%
import sys
import os
import glob
import re
from google.colab import drive
import numpy as np
import math
import random
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
import tensorflow as tf
import keras
from keras import models

device_names = tf.config.list_physical_devices('GPU')
print(device_names)

if tf.test.gpu_device_name() != "/device:GPU:0":
  print("raise SystemError('GPU device not found')")
print('Found GPU at: {}'.format(device_names))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Found GPU at: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Data Generator, this is used to provide to the training(fit) method
#one batch of data at a time.  This is needed because all of the data cannot fit into memory at the same
#time, so it needs to be loaded by the batch.
#
#This uses a custom class for this, with expected standard methods __init__, __len__, and __getitem__
#The __init__ method simply sets some internal values us batch size, overall lengths, etc.
#
#The __len__ method returns the number of batches.
#The __getitem__  method loads from file the appropriatte batch: X(the image), and Y(the class variable) and
#returns it to the fit method.
class DataGenerator(keras.utils.Sequence):
  def __init__(self, cnn_use, numpy_dir, total_size, batch_size=12):
    self.cnn_use = cnn_use
    self.total_size = total_size
    self.batch_size = batch_size
    self.numpy_dir = numpy_dir

  def __len__(self):
    return int(self.total_size / self.batch_size)

  def __getitem__(self, subset_index):
    X = np.load(f"{self.numpy_dir}/{self.cnn_use}_data_X_{subset_index}.npy")
    Y = np.load(f"{self.numpy_dir}/{self.cnn_use}_data_Y_{subset_index}.npy")
    return X, Y


#This method work very similarly to __getitem__ in the dataGenerator of the training script.
#but is standalone, not part of the DataGenerator Class.  It is used to be
#able to extract the test and validate data itself in order to perform
#manual checks on the algorithms performance(using predict, instead of evaluate)

def get_validate_X_Y_Z(numpy_dir, subset_index):
    X = np.load(f"{numpy_dir}/validate_data_X_{subset_index}.npy")
    Y = np.load(f"{numpy_dir}/validate_data_Y_{subset_index}.npy")
    Z = np.load(f"{numpy_dir}/validate_data_Z_{subset_index}.npy")
    return X, Y, Z

def get_test_X_Y_Z(numpy_dir, subset_index):
    X = np.load(f"{numpy_dir}/test_data_X_{subset_index}.npy")
    Y = np.load(f"{numpy_dir}/test_data_Y_{subset_index}.npy")
    Z = np.load(f"{numpy_dir}/test_data_Z_{subset_index}.npy")
    return X, Y, Z

# %%
#Previously all training, validate, and test data was loaded from image files and saved in numpy format in batches of 12.
#This grabs those numpy files from my google drive and copies them to the runtime drive for this session.
#Do it this way the "dataGenerator" is able to load the data from the local machine to save time during training, validation, and testing.
# !date
drive.mount('/content/drive',force_remount=True)
my_dir = "attempt10"
remote_image_dir = f"/content/drive/MyDrive/Colab Notebooks/{my_dir}"
remote_numpy_dir = f"{remote_image_dir}"
glob_string = f"{remote_numpy_dir}/*.npy"
local_numpy_dir = "/tmp/rpineau_numpy"
os.system(f"mkdir {local_numpy_dir}")

os.system(f"cd \"{remote_numpy_dir}\" && cp test.tgz {local_numpy_dir}/test.tgz")
os.system(f"cd \"{remote_numpy_dir}\" && cp validate.tgz {local_numpy_dir}/validate.tgz")
os.system(f"cd \"{remote_numpy_dir}\" && cp keras_cnn_model_VGG19.keras {local_numpy_dir}/keras_cnn_model.keras")
os.system(f"cd \"{local_numpy_dir}\" && /usr/bin/tar -zxpvf test.tgz")
os.system(f"cd \"{local_numpy_dir}\" && /usr/bin/tar -zxpvf validate.tgz")

# !date
# Out:
# Thu Apr 11 08:39:44 PM UTC 2024
# Mounted at /content/drive
# Thu Apr 11 08:40:33 PM UTC 2024

# %%
#Need to count the entries contained in all the numpy files.
#Z contains the original image_id.
#Since Z is easy to load, only count Z.

these_counts = {"train":0,"validate":0,"test":0}

#for i in ["train","validate","test"]:
for i in ["validate","test"]:
  glob_string = f"{local_numpy_dir}/{i}_data_Z_*.npy"
  np_list = glob.glob(os.path.join("", glob_string))
  for n in np_list:
    thisZ = np.load(n)
    these_counts[i] += len(thisZ)

print(f"{these_counts}")
# Out:
# {'train': 0, 'validate': 228, 'test': 228}

# %%
#Initialize the test  DataGenerator(as explained above in the class definition)
test_generator = DataGenerator("test",local_numpy_dir,these_counts["test"],batch_size=12)
validate_generator = DataGenerator("validate",local_numpy_dir,these_counts["validate"],batch_size=12)

# %%
model_file = f"{local_numpy_dir}/keras_cnn_model.keras"
model = keras.models.load_model(model_file)

# %%
val_loss,val_acc = model.evaluate(validate_generator)
print(f"MODEL1: Val Loss: {np.round(val_loss,3)} Val Accuracy: {np.round(val_acc*100,3)}%")

test_loss,test_acc = model.evaluate(test_generator)
print(f"MODEL1: Test Loss: {np.round(test_loss,3)} Test Accuracy: {np.round(test_acc*100,3)}%")
# Out:
# 19/19 [==============================] - 5s 26ms/step - loss: 0.6934 - accuracy: 0.5175
# MODEL1: Val Loss: 0.693 Val Accuracy: 51.754%
# 19/19 [==============================] - 1s 26ms/step - loss: 0.6939 - accuracy: 0.4825
# MODEL1: Test Loss: 0.694 Test Accuracy: 48.246%

# %%
this_dir = f"{local_numpy_dir}"

Y_test_all = []
Y_all = []
Z_all = []

for i in range(0,int(these_counts["test"]/12)):
  X,Y,Z = get_test_X_Y_Z(this_dir,i)
  Y_test = model.predict(X, verbose=0)
  Y_test = np.round(Y_test).flatten()
  Y_test_all = np.append(Y_test_all,Y_test,axis=0)
  Y_all = np.append(Y_all,Y,axis=0)
  Z_all = np.append(Z_all,Z,axis=0)

n=0
for y in Y_test_all:
  print(f"Predicted Y is {Y_test_all[n]} Actual Y is {Y_all[n]} from file {Z_all[n]}")
  n = n+1
# Out:
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/34117_1140358125.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/10314_2040932567.png
# Predicted Y is 1.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/29526_387006708.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/59347_931918335.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/25432_2058514481.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/64821_680464985.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/32527_701842729.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/26161_2095705735.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/36706_1533561690.png
# Predicted Y is 1.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/20600_624165549.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/41185_1455026297.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/13845_922229804.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/23774_586400750.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/39677_1140395794.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/16879_2049843466.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/18405_128680709.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/10038_850559196.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/46607_1575898040.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/4953_1788011383.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/45_2102838312.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/20621_1235421825.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/15268_1398189039.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/46034_911642383.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/33843_1167406220.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/25523_449544592.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/59875_1333731298.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/46274_2144094168.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/42132_787978004.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/12522_212923136.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/53115_1903183388.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/4824_1764642297.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/37012_531540217.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/58221_1327812214.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/18709_403704207.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/27344_1661167822.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/16518_442815464.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/38944_2006372875.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/18330_1860449038.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/37047_855825025.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/29228_225508700.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/47128_1726612128.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/7164_2065405214.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/13868_1631171838.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/17222_637984831.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/20942_558552648.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/7591_1199136621.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/25323_396189007.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/63226_1084546948.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/56308_1609200371.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/13331_1360800566.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/6123_1376021194.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/57525_550007476.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/59457_1441747151.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/49833_892284493.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/59705_1313534339.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/54463_706555257.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/26700_1878879697.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/36278_856132213.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/44758_1728424838.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/37573_1344523058.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test/51710_1944654019.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt10/test/31581_1732965874.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt10/test
png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/4787_1276270172.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/40576_291976928.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/19649_196368921.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/6099_1429918918.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/45868_1775029041.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/1234_43382331.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/53636_2044242754.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/59347_2040824439.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/18771_786354466.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/18118_477809345.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/34391_1639391869.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/10589_195400299.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/6303_1106334075.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/5769_1620633879.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/21720_1900007287.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/53946_2125610822.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/57229_1874344878.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/5438_2013353273.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/46106_1180358825.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/30842_731839572.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/25679_2041280578.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/49636_1520451015.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/31582_435931040.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/55301_625147236.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/50250_1019022758.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/65198_712545807.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/2989_406764921.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/11952_363565620.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/2938_872443919.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/20009_936994890.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/53343_1721695713.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/35641_1646496367.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/26871_568161399.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/52327_1266936818.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/4135_354138937.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/12392_1420153030.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/24240_1988059650.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/60410_1597116280.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/61825_1951468322.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/37836_1312846125.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/9840_111786935.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/11919_1007401721.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/53659_1125098485.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/8631_280870762.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/37163_1351450930.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/22502_1766210915.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/50644_1408030705.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/63453_2126290731.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/33594_77581347.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/49313_1555150117.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/38727_1338411990.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/31864_873474308.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/58195_480438532.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/4888_1705616801.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/5911_1491483248.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/26232_1378580532.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/32087_1919147280.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/60001_1890233822.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/1759_1005049159.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/37105_1352718656.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/10130_1672636630.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/63226_593509035.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/32112_242150959.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/61568_85804262.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/1878_1609298443.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/2489_1930646527.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/48493_104113094.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/60033_1188802546.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/21445_468265579.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/38188_1768430207.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/30712_2031323106.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/11341_1096308702.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/28785_216760793.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/21315_842119228.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt10/test/46775_503256692.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/50600_1317862974.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/16145_230036674.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/26974_592583896.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/32923_696658722.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/49176_1270133082.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/51498_235064489.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/31107_56487741.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt10/test/38311_300211801.png

# %%
def calc_confusion_values(Y,Y_test):
  TP = 0
  TN = 0
  FP = 0
  FN = 0
  n = 0
  for y in Y:
    if Y[n] == 1 and Y_test[n] == 1:
      TP = TP+1
    elif Y[n] == 0 and Y_test[n] == 1:
      FP = FP+1
    elif Y[n] == 0 and Y_test[n] == 0:
      TN = TN+1
    elif Y[n] == 1 and Y_test[n] == 0:
      FN = FN+1
    n = n+1

  cf = np.empty([2,2])
  cf[0,0] = TN
  cf[0,1] = FP
  cf[1,0] = FN
  cf[1,1] = TP
  return(cf)


#        TPR (recall) = TP / P
#        ACC (accuracy) = (TP + TN) / (P + N)
#        PPV (precison) = TP / (TP + FP)
def calc_recall(cf):
  TN, FP, FN, TP=cf.ravel()
  return(TP/(TP+FN))

def calc_precision(cf):
  TN, FP, FN, TP=cf.ravel()
  return(TP/(TP+FP))

def calc_accuracy(cf):
  TN, FP, FN, TP=cf.ravel()
  return((TP+TN)/(TP+FP+TN+FN))

# %%
cf=calc_confusion_values(Y_all, Y_test_all)
TN, FP, FN, TP=cf.ravel()

print("Confusion Matrix:")
print(cf)
print("")
print("TP: ", TP,", FP: ", FP,", TN: ", TN,", FN:", FN)

recall = round(calc_recall(cf),3)
precision = round(calc_precision(cf),3)
accuracy = round(calc_accuracy(cf)*100,3)

print(f"Recall: {recall} Precison: {precision} Accuracy: {accuracy}%")
# Out:
# Confusion Matrix:
# [[97. 19.]
#  [99. 13.]]
#
# TP:  13.0 , FP:  19.0 , TN:  97.0 , FN: 99.0
# Recall: 0.116 Precison: 0.406 Accuracy: 48.246%
