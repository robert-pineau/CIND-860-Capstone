# %% [markdown]
# <a href="https://colab.research.google.com/github/robert-pineau/CIND-860-Capstone/blob/main/CIND860_TL_RESNET50_full_augment_cc_only_evaluate_only_fullset_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CIND860: W24: Advanced Data Analytics Project
# Robert M. Pineau
# 941-049-371

# %%
import sys
import os
import glob
import re
from google.colab import drive
import numpy as np
import math
import random
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
import tensorflow as tf
import keras
from keras import models

device_names = tf.config.list_physical_devices('GPU')
print(device_names)

if tf.test.gpu_device_name() != "/device:GPU:0":
  print("raise SystemError('GPU device not found')")
print('Found GPU at: {}'.format(device_names))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Found GPU at: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Data Generator, this is used to provide to the training(fit) method
#one batch of data at a time.  This is needed because all of the data cannot fit into memory at the same
#time, so it needs to be loaded by the batch.
#
#This uses a custom class for this, with expected standard methods __init__, __len__, and __getitem__
#The __init__ method simply sets some internal values us batch size, overall lengths, etc.
#
#The __len__ method returns the number of batches.
#The __getitem__  method loads from file the appropriatte batch: X(the image), and Y(the class variable) and
#returns it to the fit method.
class DataGenerator(keras.utils.Sequence):
  def __init__(self, cnn_use, numpy_dir, total_size, batch_size=12):
    self.cnn_use = cnn_use
    self.total_size = total_size
    self.batch_size = batch_size
    self.numpy_dir = numpy_dir

  def __len__(self):
    return int(self.total_size / self.batch_size)

  def __getitem__(self, subset_index):
    X = np.load(f"{self.numpy_dir}/{self.cnn_use}_data_X_{subset_index}.npy")
    Y = np.load(f"{self.numpy_dir}/{self.cnn_use}_data_Y_{subset_index}.npy")
    return X, Y


#This method work very similarly to __getitem__ in the dataGenerator of the training script.
#but is standalone, not part of the DataGenerator Class.  It is used to be
#able to extract the test and validate data itself in order to perform
#manual checks on the algorithms performance(using predict, instead of evaluate)

def get_validate_X_Y_Z(numpy_dir, subset_index):
    X = np.load(f"{numpy_dir}/validate_data_X_{subset_index}.npy")
    Y = np.load(f"{numpy_dir}/validate_data_Y_{subset_index}.npy")
    Z = np.load(f"{numpy_dir}/validate_data_Z_{subset_index}.npy")
    return X, Y, Z

def get_test_X_Y_Z(numpy_dir, subset_index):
    X = np.load(f"{numpy_dir}/test_data_X_{subset_index}.npy")
    Y = np.load(f"{numpy_dir}/test_data_Y_{subset_index}.npy")
    Z = np.load(f"{numpy_dir}/test_data_Z_{subset_index}.npy")
    return X, Y, Z

# %%
#Previously all training, validate, and test data was loaded from image files and saved in numpy format in batches of 12.
#This grabs those numpy files from my google drive and copies them to the runtime drive for this session.
#Do it this way the "dataGenerator" is able to load the data from the local machine to save time during training, validation, and testing.
# !date
drive.mount('/content/drive',force_remount=True)
my_dir = "attempt9"
remote_image_dir = f"/content/drive/MyDrive/Colab Notebooks/{my_dir}"
remote_numpy_dir = f"{remote_image_dir}"
glob_string = f"{remote_numpy_dir}/*.npy"
local_numpy_dir = "/tmp/rpineau_numpy"
os.system(f"mkdir {local_numpy_dir}")

os.system(f"cd \"{remote_numpy_dir}\" && cp full_test.tgz {local_numpy_dir}/test.tgz")
#os.system(f"cd \"{remote_numpy_dir}\" && cp validate.tgz {local_numpy_dir}/validate.tgz")
os.system(f"cd \"{remote_numpy_dir}\" && cp keras_cnn_model_RESNET50.keras {local_numpy_dir}/keras_cnn_model.keras")
os.system(f"cd \"{local_numpy_dir}\" && /usr/bin/tar -zxpvf test.tgz")
#os.system(f"cd \"{local_numpy_dir}\" && /usr/bin/tar -zxpvf validate.tgz")

# !date
# Out:
# Fri Apr 12 04:22:46 PM UTC 2024
# Mounted at /content/drive
# Fri Apr 12 04:34:16 PM UTC 2024

# %%
#Need to count the entries contained in all the numpy files.
#Z contains the original image_id.
#Since Z is easy to load, only count Z.

these_counts = {"train":0,"validate":0,"test":0}

#for i in ["train","validate","test"]:
for i in ["test"]:
  glob_string = f"{local_numpy_dir}/{i}_data_Z_*.npy"
  np_list = glob.glob(os.path.join("", glob_string))
  for n in np_list:
    thisZ = np.load(n)
    these_counts[i] += len(thisZ)

print(f"{these_counts}")
# Out:
# {'train': 0, 'validate': 0, 'test': 54036}

# %%
#Initialize the test  DataGenerator(as explained above in the class definition)
test_generator = DataGenerator("test",local_numpy_dir,these_counts["test"],batch_size=12)
#validate_generator = DataGenerator("validate",local_numpy_dir,these_counts["validate"],batch_size=12)

# %%
model_file = f"{local_numpy_dir}/keras_cnn_model.keras"
model = keras.models.load_model(model_file)

# %%
#val_loss,val_acc = model.evaluate(validate_generator)
#print(f"MODEL1: Val Loss: {np.round(val_loss,3)} Val Accuracy: {np.round(val_acc*100,3)}%")

test_loss,test_acc = model.evaluate(test_generator)
print(f"MODEL1: Test Loss: {np.round(test_loss,3)} Test Accuracy: {np.round(test_acc*100,3)}%")
# Out:
# 4503/4503 [==============================] - 376s 82ms/step - loss: 0.7115 - accuracy: 0.6526
# MODEL1: Test Loss: 0.711 Test Accuracy: 65.256%

# %%
this_dir = f"{local_numpy_dir}"

Y_test_all = []
Y_all = []
Z_all = []

for i in range(0,int(these_counts["test"]/12)):
  X,Y,Z = get_test_X_Y_Z(this_dir,i)
  Y_test = model.predict(X, verbose=0)
  Y_test = np.round(Y_test).flatten()
  Y_test_all = np.append(Y_test_all,Y_test,axis=0)
  Y_all = np.append(Y_all,Y,axis=0)
  Z_all = np.append(Z_all,Z,axis=0)

n=0
for y in Y_test_all:
  print(f"Predicted Y is {Y_test_all[n]} Actual Y is {Y_all[n]} from file {Z_all[n]}")
  n = n+1

# %%
print("CORRECT PREDS")
n=0
for y in Y_all:
  if Y_test_all[n] == Y_all[n]:
    #pass
    print(f"Predicted Y is {Y_test_all[n]} Actual Y is {Y_all[n]} File {Z_all[n]}")
  n = n+1

print("INCORRECT PREDS")
n=0
for y in Y_all:
  if Y_test_all[n] != Y_all[n]:
    #pass
    print(f"Predicted Y is {Y_test_all[n]} Actual Y is {Y_all[n]} File {Z_all[n]}")
  n = n+1
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1986957375.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1813226588.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/17065562.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1782837244.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1986667926.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1110971857.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/527468376.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/910866531.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1721908966.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1862605458.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/819191215.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1388981431.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2062738240.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/905336514.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1945539812.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1251390964.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1916918516.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/105849292.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/203264527.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2133086127.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/326432745.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1869321369.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1476216224.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2124949399.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/490470522.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2147152968.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1208190426.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/265208667.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1915887601.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1667793721.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/587859176.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/451676567.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/894715101.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/865736503.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/856066669.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1029484673.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/192837763.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1399181675.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1106513663.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1901143129.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1819681369.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1867124726.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/513835084.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1915717529.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/776281370.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1479028606.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/361055371.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2002547124.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/842908419.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/540377363.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/21170068.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1531044870.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1752210506.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/156440604.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/854403872.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6
png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1499398402.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1868429850.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/848734402.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/435812768.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/332282652.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/266491339.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1562121501.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1493617585.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/118067901.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/989432941.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/523443845.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1679207231.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/923445040.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1009219654.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1225978295.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1652798631.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1979804169.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/33429299.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1638567238.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1446814640.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1978911815.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/189439140.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1632529538.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/464247139.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/293206952.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/3732260.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1742510349.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/448315044.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/711094937.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/651809926.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1325623407.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/371298129.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1613105876.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/913152920.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/819430609.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1392193422.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1633199861.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2133430485.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2077442875.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1928891968.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/992508154.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1739681505.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/335016374.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1437179461.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/792015341.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/358366490.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/650780115.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1763241662.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1352217793.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1526983611.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1326164928.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1521983813.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1183425241.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1114821406.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1015890109.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1469558197.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/461138230.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/557770119.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1954631599.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2012821382.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/884205777.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1243836449.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/829934522.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1631171838.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/950714814.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2004378780.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/413870340.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/404533486.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/34482665.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/524184701.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1097412472.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1178925052.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1175068171.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1131224899.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1657046304.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1281416430.png
# Predicted Y is 1.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/test6/835658415.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1828771047.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1137001684.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1166403040.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2144609476.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/718312826.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/915880383.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1686535137.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2136296361.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1890709032.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1804490633.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/695067665.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/330743100.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/851331552.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1387981423.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/417427813.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/673118377.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1440941657.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1497182415.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1272574741.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1619364877.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1636430409.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2064903913.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/774199576.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/993790581.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1698405286.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1179596040.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/434530210.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/364955200.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1706871568.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1622207304.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/725979890.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/53586452.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1004071591.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/868405364.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/440050593.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/879741629.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1398600341.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1840955817.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/265886680.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1753827391.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/371536710.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/985189218.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1263283397.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1150248458.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1420501224.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/870445365.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1822161446.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/782712243.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1638731798.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/441643532.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/771224338.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1496941352.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1097870671.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/2037337185.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1042332351.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1019558095.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1134797478.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1642928141.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/753983342.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/864730731.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/742029620.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1179504072.png
# Predicted Y is 0.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/test6/1693306484.png
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
def calc_confusion_values(Y,Y_test):
  TP = 0
  TN = 0
  FP = 0
  FN = 0
  n = 0
  for y in Y:
    if Y[n] == 1 and Y_test[n] == 1:
      TP = TP+1
    elif Y[n] == 0 and Y_test[n] == 1:
      FP = FP+1
    elif Y[n] == 0 and Y_test[n] == 0:
      TN = TN+1
    elif Y[n] == 1 and Y_test[n] == 0:
      FN = FN+1
    n = n+1

  cf = np.empty([2,2])
  cf[0,0] = TN
  cf[0,1] = FP
  cf[1,0] = FN
  cf[1,1] = TP
  return(cf)


#        TPR (recall) = TP / P
#        ACC (accuracy) = (TP + TN) / (P + N)
#        PPV (precison) = TP / (TP + FP)
def calc_recall(cf):
  TN, FP, FN, TP=cf.ravel()
  return(TP/(TP+FN))

def calc_precision(cf):
  TN, FP, FN, TP=cf.ravel()
  return(TP/(TP+FP))

def calc_accuracy(cf):
  TN, FP, FN, TP=cf.ravel()
  return((TP+TN)/(TP+FP+TN+FN))

# %%
cf=calc_confusion_values(Y_all, Y_test_all)
TN, FP, FN, TP=cf.ravel()

print("Confusion Matrix:")
print(cf)
print("")
print("TP: ", TP,", FP: ", FP,", TN: ", TN,", FN:", FN)

recall = round(calc_recall(cf),3)
precision = round(calc_precision(cf),3)
accuracy = round(calc_accuracy(cf)*100,3)

print(f"Recall: {recall} Precison: {precision} Accuracy: {accuracy}%")
# Out:
# Confusion Matrix:
# [[34888. 18323.]
#  [  451.   374.]]
#
# TP:  374.0 , FP:  18323.0 , TN:  34888.0 , FN: 451.0
# Recall: 0.453 Precison: 0.02 Accuracy: 65.256%
