# %% [markdown]
# <a href="https://colab.research.google.com/github/robert-pineau/CIND-860-Capstone/blob/main/CIND860_TL_VGG19_full_augment_cc_only_evaluate_only.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CIND860: W24: Advanced Data Analytics Project
# Robert M. Pineau
# 941-049-371

# %%
import sys
import os
import glob
import re
from google.colab import drive
import numpy as np
import math
import random
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
import tensorflow as tf
import keras
from keras import models

device_names = tf.config.list_physical_devices('GPU')
print(device_names)

if tf.test.gpu_device_name() != "/device:GPU:0":
  print("raise SystemError('GPU device not found')")
print('Found GPU at: {}'.format(device_names))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Found GPU at: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Data Generator, this is used to provide to the training(fit) method
#one batch of data at a time.  This is needed because all of the data cannot fit into memory at the same
#time, so it needs to be loaded by the batch.
#
#This uses a custom class for this, with expected standard methods __init__, __len__, and __getitem__
#The __init__ method simply sets some internal values us batch size, overall lengths, etc.
#
#The __len__ method returns the number of batches.
#The __getitem__  method loads from file the appropriatte batch: X(the image), and Y(the class variable) and
#returns it to the fit method.
class DataGenerator(keras.utils.Sequence):
  def __init__(self, cnn_use, numpy_dir, total_size, batch_size=12):
    self.cnn_use = cnn_use
    self.total_size = total_size
    self.batch_size = batch_size
    self.numpy_dir = numpy_dir

  def __len__(self):
    return int(self.total_size / self.batch_size)

  def __getitem__(self, subset_index):
    X = np.load(f"{self.numpy_dir}/{self.cnn_use}_data_X_{subset_index}.npy")
    Y = np.load(f"{self.numpy_dir}/{self.cnn_use}_data_Y_{subset_index}.npy")
    return X, Y


#This method work very similarly to __getitem__ in the dataGenerator of the training script.
#but is standalone, not part of the DataGenerator Class.  It is used to be
#able to extract the test and validate data itself in order to perform
#manual checks on the algorithms performance(using predict, instead of evaluate)

def get_validate_X_Y_Z(numpy_dir, subset_index):
    X = np.load(f"{numpy_dir}/validate_data_X_{subset_index}.npy")
    Y = np.load(f"{numpy_dir}/validate_data_Y_{subset_index}.npy")
    Z = np.load(f"{numpy_dir}/validate_data_Z_{subset_index}.npy")
    return X, Y, Z

def get_test_X_Y_Z(numpy_dir, subset_index):
    X = np.load(f"{numpy_dir}/test_data_X_{subset_index}.npy")
    Y = np.load(f"{numpy_dir}/test_data_Y_{subset_index}.npy")
    Z = np.load(f"{numpy_dir}/test_data_Z_{subset_index}.npy")
    return X, Y, Z

# %%
#Previously all training, validate, and test data was loaded from image files and saved in numpy format in batches of 12.
#This grabs those numpy files from my google drive and copies them to the runtime drive for this session.
#Do it this way the "dataGenerator" is able to load the data from the local machine to save time during training, validation, and testing.
# !date
drive.mount('/content/drive',force_remount=True)
my_dir = "attempt9"
remote_image_dir = f"/content/drive/MyDrive/Colab Notebooks/{my_dir}"
remote_numpy_dir = f"{remote_image_dir}"
glob_string = f"{remote_numpy_dir}/*.npy"
local_numpy_dir = "/tmp/rpineau_numpy"
os.system(f"mkdir {local_numpy_dir}")

os.system(f"cd \"{remote_numpy_dir}\" && cp test.tgz {local_numpy_dir}/test.tgz")
os.system(f"cd \"{remote_numpy_dir}\" && cp validate.tgz {local_numpy_dir}/validate.tgz")
os.system(f"cd \"{remote_numpy_dir}\" && cp keras_cnn_model_VGG19.keras {local_numpy_dir}/keras_cnn_model.keras")
os.system(f"cd \"{local_numpy_dir}\" && /usr/bin/tar -zxpvf test.tgz")
os.system(f"cd \"{local_numpy_dir}\" && /usr/bin/tar -zxpvf validate.tgz")

# !date
# Out:
# Thu Apr 11 07:19:37 PM UTC 2024
# Mounted at /content/drive
# Thu Apr 11 07:20:33 PM UTC 2024

# %%
#Need to count the entries contained in all the numpy files.
#Z contains the original image_id.
#Since Z is easy to load, only count Z.

these_counts = {"train":0,"validate":0,"test":0}

#for i in ["train","validate","test"]:
for i in ["validate","test"]:
  glob_string = f"{local_numpy_dir}/{i}_data_Z_*.npy"
  np_list = glob.glob(os.path.join("", glob_string))
  for n in np_list:
    thisZ = np.load(n)
    these_counts[i] += len(thisZ)

print(f"{these_counts}")
# Out:
# {'train': 0, 'validate': 216, 'test': 216}

# %%
#Initialize the test  DataGenerator(as explained above in the class definition)
test_generator = DataGenerator("test",local_numpy_dir,these_counts["test"],batch_size=12)
validate_generator = DataGenerator("validate",local_numpy_dir,these_counts["validate"],batch_size=12)

# %%
model_file = f"{local_numpy_dir}/keras_cnn_model.keras"
model = keras.models.load_model(model_file)

# %%
val_loss,val_acc = model.evaluate(validate_generator)
print(f"MODEL1: Val Loss: {np.round(val_loss,3)} Val Accuracy: {np.round(val_acc*100,3)}%")

test_loss,test_acc = model.evaluate(test_generator)
print(f"MODEL1: Test Loss: {np.round(test_loss,3)} Test Accuracy: {np.round(test_acc*100,3)}%")
# Out:
# 18/18 [==============================] - 4s 25ms/step - loss: 0.6921 - accuracy: 0.5509
# MODEL1: Val Loss: 0.692 Val Accuracy: 55.093%
# 18/18 [==============================] - 1s 26ms/step - loss: 0.6872 - accuracy: 0.5741
# MODEL1: Test Loss: 0.687 Test Accuracy: 57.407%

# %%
this_dir = f"{local_numpy_dir}"

Y_test_all = []
Y_all = []
Z_all = []

for i in range(0,int(these_counts["test"]/12)):
  X,Y,Z = get_test_X_Y_Z(this_dir,i)
  Y_test = model.predict(X, verbose=0)
  Y_test = np.round(Y_test).flatten()
  Y_test_all = np.append(Y_test_all,Y_test,axis=0)
  Y_all = np.append(Y_all,Y,axis=0)
  Z_all = np.append(Z_all,Z,axis=0)

n=0
for y in Y_test_all:
  print(f"Predicted Y is {Y_test_all[n]} Actual Y is {Y_all[n]} from file {Z_all[n]}")
  n = n+1
# Out:
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/31972_1265559005.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/57550_859566423.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/14471_2039507215.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/14941_1634151852.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/500_1942815129.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/15709_1390396834.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/43144_900970932.png
# Predicted Y is 1.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/54052_953148041.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/36660_498444217.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/48099_1542459030.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/21720_1949604033.png
# Predicted Y is 1.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/15066_110218682.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/5708_1727732567.png
# Predicted Y is 1.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/35847_2041771555.png
# Predicted Y is 1.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/23898_859173484.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/13845_198053228.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/38501_887434052.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/61929_962472006.png
# Predicted Y is 1.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/3670_87674192.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/15213_1584162944.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/27366_304090560.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/48230_1587213840.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/39748_1220490070.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/52849_2090206247.png
# Predicted Y is 1.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/6107_562044384.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/30435_63956271.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/3021_758579205.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/43880_1728318042.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/12651_382701440.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/1963_1044828729.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/9029_1906118149.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/12918_835777184.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/55095_864613243.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/37176_1987935293.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/28989_382116832.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/4953_146985323.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/58564_1081841028.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/58751_1517109723.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/47171_1934472220.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test/60033_1168039233.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/45827_884972201.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt9/test/39557_1147799985.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt9/test
png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/30435_63956271.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/3021_758579205.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/43880_1728318042.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/12651_382701440.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/1963_1044828729.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/9029_1906118149.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/12918_835777184.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/55095_864613243.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/28989_382116832.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/4953_146985323.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/58564_1081841028.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/47171_1934472220.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/60033_1168039233.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/44121_546226529.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/57153_676165775.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/28344_2037343606.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/10638_1696075167.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/11094_1882170663.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/8403_1710665236.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/11341_1810004579.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/8641_2120521410.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/62401_1606971612.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/5235_811649706.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/3713_1056851936.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/33588_409921956.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/23693_1555452504.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/63226_32033063.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/61019_1303317067.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/45848_2102657462.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/2938_247535701.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/4202_39658249.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/39747_934952606.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/34823_1928170517.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/50583_1497446939.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/7196_976434791.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/63053_1922119353.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt9/test/20523_987633153.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/6018_1680138718.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/44062_212955895.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/22616_2115811863.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/8732_791267021.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/8631_155909056.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/2133_1976974923.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/6659_1877249993.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/25709_1410656943.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/24916_801684731.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/39280_334248774.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/51498_1481006643.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/30435_1261298563.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/55483_457072769.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/25909_1201889471.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/3626_1942920371.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/65224_1876649852.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/21923_1055241270.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt9/test/40085_1787013215.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/44709_646346502.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/11817_1812305728.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/47128_270089098.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/13101_345896545.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/46905_1342667639.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/9201_18384498.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/50644_1779556127.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt9/test/10151_2056985886.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/47055_11944138.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/60410_825403089.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt9/test/47253_218360753.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/12195_91797551.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/60617_2047450417.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/53358_1137564107.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/50600_772542553.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/6853_373068997.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/106_76321767.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/36748_240108548.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/31750_1253104075.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/25187_1207987797.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt9/test/56632_1438737826.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/16346_1171817874.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/40576_2146445857.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/38537_1655223848.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/54085_1006201562.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/50740_1717606646.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt9/test/34391_1817841876.png

# %%
def calc_confusion_values(Y,Y_test):
  TP = 0
  TN = 0
  FP = 0
  FN = 0
  n = 0
  for y in Y:
    if Y[n] == 1 and Y_test[n] == 1:
      TP = TP+1
    elif Y[n] == 0 and Y_test[n] == 1:
      FP = FP+1
    elif Y[n] == 0 and Y_test[n] == 0:
      TN = TN+1
    elif Y[n] == 1 and Y_test[n] == 0:
      FN = FN+1
    n = n+1

  cf = np.empty([2,2])
  cf[0,0] = TN
  cf[0,1] = FP
  cf[1,0] = FN
  cf[1,1] = TP
  return(cf)


#        TPR (recall) = TP / P
#        ACC (accuracy) = (TP + TN) / (P + N)
#        PPV (precison) = TP / (TP + FP)
def calc_recall(cf):
  TN, FP, FN, TP=cf.ravel()
  return(TP/(TP+FN))

def calc_precision(cf):
  TN, FP, FN, TP=cf.ravel()
  return(TP/(TP+FP))

def calc_accuracy(cf):
  TN, FP, FN, TP=cf.ravel()
  return((TP+TN)/(TP+FP+TN+FN))

# %%
cf=calc_confusion_values(Y_all, Y_test_all)
TN, FP, FN, TP=cf.ravel()

print("Confusion Matrix:")
print(cf)
print("")
print("TP: ", TP,", FP: ", FP,", TN: ", TN,", FN:", FN)

recall = round(calc_recall(cf),3)
precision = round(calc_precision(cf),3)
accuracy = round(calc_accuracy(cf)*100,3)

print(f"Recall: {recall} Precison: {precision} Accuracy: {accuracy}%")
# Out:
# Confusion Matrix:
# [[109.   8.]
#  [ 84.  15.]]
#
# TP:  15.0 , FP:  8.0 , TN:  109.0 , FN: 84.0
# Recall: 0.152 Precison: 0.652 Accuracy: 57.407%
