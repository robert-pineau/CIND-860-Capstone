# %% [markdown]
# <a href="https://colab.research.google.com/github/robert-pineau/CIND-860-Capstone/blob/main/CIND860_TL_VGG19_full_augment_cc_and_mlo_evaluate_only.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CIND860: W24: Advanced Data Analytics Project
# Robert M. Pineau
# 941-049-371

# %%
import sys
import os
import glob
import re
from google.colab import drive
import numpy as np
import math
import random
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
import tensorflow as tf
import keras
from keras import models

device_names = tf.config.list_physical_devices('GPU')
print(device_names)

if tf.test.gpu_device_name() != "/device:GPU:0":
  print("raise SystemError('GPU device not found')")
print('Found GPU at: {}'.format(device_names))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Found GPU at: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Data Generator, this is used to provide to the training(fit) method
#one batch of data at a time.  This is needed because all of the data cannot fit into memory at the same
#time, so it needs to be loaded by the batch.
#
#This uses a custom class for this, with expected standard methods __init__, __len__, and __getitem__
#The __init__ method simply sets some internal values us batch size, overall lengths, etc.
#
#The __len__ method returns the number of batches.
#The __getitem__  method loads from file the appropriatte batch: X(the image), and Y(the class variable) and
#returns it to the fit method.
class DataGenerator(keras.utils.Sequence):
  def __init__(self, cnn_use, numpy_dir, total_size, batch_size=12):
    self.cnn_use = cnn_use
    self.total_size = total_size
    self.batch_size = batch_size
    self.numpy_dir = numpy_dir

  def __len__(self):
    return int(self.total_size / self.batch_size)

  def __getitem__(self, subset_index):
    X = np.load(f"{self.numpy_dir}/{self.cnn_use}_data_X_{subset_index}.npy")
    Y = np.load(f"{self.numpy_dir}/{self.cnn_use}_data_Y_{subset_index}.npy")
    return X, Y


#This method work very similarly to __getitem__ in the dataGenerator of the training script.
#but is standalone, not part of the DataGenerator Class.  It is used to be
#able to extract the test and validate data itself in order to perform
#manual checks on the algorithms performance(using predict, instead of evaluate)

def get_validate_X_Y_Z(numpy_dir, subset_index):
    X = np.load(f"{numpy_dir}/validate_data_X_{subset_index}.npy")
    Y = np.load(f"{numpy_dir}/validate_data_Y_{subset_index}.npy")
    Z = np.load(f"{numpy_dir}/validate_data_Z_{subset_index}.npy")
    return X, Y, Z

def get_test_X_Y_Z(numpy_dir, subset_index):
    X = np.load(f"{numpy_dir}/test_data_X_{subset_index}.npy")
    Y = np.load(f"{numpy_dir}/test_data_Y_{subset_index}.npy")
    Z = np.load(f"{numpy_dir}/test_data_Z_{subset_index}.npy")
    return X, Y, Z

# %%
#Previously all training, validate, and test data was loaded from image files and saved in numpy format in batches of 12.
#This grabs those numpy files from my google drive and copies them to the runtime drive for this session.
#Do it this way the "dataGenerator" is able to load the data from the local machine to save time during training, validation, and testing.
# !date
drive.mount('/content/drive',force_remount=True)
my_dir = "attempt8"
remote_image_dir = f"/content/drive/MyDrive/Colab Notebooks/{my_dir}"
remote_numpy_dir = f"{remote_image_dir}"
glob_string = f"{remote_numpy_dir}/*.npy"
local_numpy_dir = "/tmp/rpineau_numpy"
os.system(f"mkdir {local_numpy_dir}")

os.system(f"cd \"{remote_numpy_dir}\" && cp test.tgz {local_numpy_dir}/test.tgz")
os.system(f"cd \"{remote_numpy_dir}\" && cp validate.tgz {local_numpy_dir}/validate.tgz")
os.system(f"cd \"{remote_numpy_dir}\" && cp keras_cnn_model_VGG19.keras {local_numpy_dir}/keras_cnn_model.keras")
os.system(f"cd \"{local_numpy_dir}\" && /usr/bin/tar -zxpvf test.tgz")
os.system(f"cd \"{local_numpy_dir}\" && /usr/bin/tar -zxpvf validate.tgz")

# !date
# Out:
# Thu Apr 11 06:19:38 PM UTC 2024
# Mounted at /content/drive
# Thu Apr 11 06:20:41 PM UTC 2024

# %%
#Need to count the entries contained in all the numpy files.
#Z contains the original image_id.
#Since Z is easy to load, only count Z.

these_counts = {"train":0,"validate":0,"test":0}

#for i in ["train","validate","test"]:
for i in ["validate","test"]:
  glob_string = f"{local_numpy_dir}/{i}_data_Z_*.npy"
  np_list = glob.glob(os.path.join("", glob_string))
  for n in np_list:
    thisZ = np.load(n)
    these_counts[i] += len(thisZ)

print(f"{these_counts}")
# Out:
# {'train': 0, 'validate': 456, 'test': 456}

# %%
#Initialize the test  DataGenerator(as explained above in the class definition)
test_generator = DataGenerator("test",local_numpy_dir,these_counts["test"],batch_size=12)
validate_generator = DataGenerator("validate",local_numpy_dir,these_counts["validate"],batch_size=12)

# %%
model_file = f"{local_numpy_dir}/keras_cnn_model.keras"
model = keras.models.load_model(model_file)

# %%
val_loss,val_acc = model.evaluate(validate_generator)
print(f"MODEL1: Val Loss: {np.round(val_loss,3)} Val Accuracy: {np.round(val_acc*100,3)}%")

test_loss,test_acc = model.evaluate(test_generator)
print(f"MODEL1: Test Loss: {np.round(test_loss,3)} Test Accuracy: {np.round(test_acc*100,3)}%")
# Out:
# 38/38 [==============================] - 5s 26ms/step - loss: 0.6928 - accuracy: 0.5154
# MODEL1: Val Loss: 0.693 Val Accuracy: 51.535%
# 38/38 [==============================] - 1s 26ms/step - loss: 0.6941 - accuracy: 0.5000
# MODEL1: Test Loss: 0.694 Test Accuracy: 50.0%

# %%
this_dir = f"{local_numpy_dir}"

Y_test_all = []
Y_all = []
Z_all = []

for i in range(0,int(these_counts["test"]/12)):
  X,Y,Z = get_test_X_Y_Z(this_dir,i)
  Y_test = model.predict(X, verbose=0)
  Y_test = np.round(Y_test).flatten()
  Y_test_all = np.append(Y_test_all,Y_test,axis=0)
  Y_all = np.append(Y_all,Y,axis=0)
  Z_all = np.append(Z_all,Z,axis=0)

n=0
for y in Y_test_all:
  print(f"Predicted Y is {Y_test_all[n]} Actual Y is {Y_all[n]} from file {Z_all[n]}")
  n = n+1
# Out:
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/42016_1123844215.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/46662_712244599.png
# Predicted Y is 1.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/1109_1869230850.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/64534_1420658905.png
# Predicted Y is 1.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/17692_286249073.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/3895_195309643.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/49485_109045962.png
# Predicted Y is 1.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/47280_1577937072.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/34262_1932409605.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/55281_395854967.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/22299_1585651779.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/17222_568569032.png
# Predicted Y is 1.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/3411_821274420.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/47129_1926732125.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/61600_1244333693.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/43615_130949491.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/34993_322548051.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/32565_2088811609.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/54967_1048421920.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/36174_1018324731.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/34007_1767765653.png
# Predicted Y is 1.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/42074_1809900676.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/9633_569110238.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/54084_852493177.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/13845_1772525431.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/25178_1329415270.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/31750_1253104075.png
# Predicted Y is 1.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/53115_1903183388.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/30363_192291098.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/12981_1440814072.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/32743_857882013.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/64594_604845804.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/35421_1954231968.png
# Predicted Y is 0.0 Actual Y is 1.0 from file /mnt/wd/CIND860/database/attempt8/test/58564_22663013.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test/7949_1889114898.png
# Predicted Y is 0.0 Actual Y is 0.0 from file /mnt/wd/CIND860/database/attempt8/test
png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/1759_1211304263.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt8/test/58408_1294871623.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/6107_562044384.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/2938_872443919.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/35864_1350237568.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/65427_808462263.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/60617_1075848024.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/53360_1859372199.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/63706_1241091399.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/11094_1882170663.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/48493_75556345.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/22502_1283804942.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt8/test/61294_1504777534.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/32740_208676208.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/61825_1335802158.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/21720_1949604033.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/63053_151272201.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/56139_1204086246.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/9707_1900919592.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/11249_1820235658.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/64437_2141319189.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/16955_846765464.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/35641_1646496367.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/500_1942815129.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/14292_287915367.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/11817_1812305728.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/64385_1032681733.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/47382_208877180.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/64449_1151546567.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/39702_399564828.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/19159_444773067.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/45137_847490588.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/13267_1222788247.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/65492_1306638994.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/55755_640788258.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/44676_630962.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/8675_1748372351.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/31582_240230808.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/26232_892289164.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/32252_831862963.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/26974_592583896.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/12153_1652537920.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/59865_1213747044.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/58398_1620798005.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/54671_1214090918.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/34962_1766220026.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/12195_100147863.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/12651_1852393673.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/15078_728564060.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/25323_106495931.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/7339_152254694.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/32770_1782876059.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/56713_238470103.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/48230_1587213840.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/21928_769477628.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/7151_396925350.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/28620_669303826.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/47055_102668587.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/21888_1472830410.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/65222_111055050.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/49176_1270133082.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/1524_1856057994.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/34987_562433892.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt8/test/47994_1048747086.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/9481_467726444.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/6668_570350557.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/13463_740921229.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/3713_1056851936.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/59322_1797886948.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/41238_1969581106.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/48171_373646784.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/46495_1751742838.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/35227_1532464574.png
# Predicted Y is 1.0 Actual Y is 0.0 File /mnt/wd/CIND860/database/attempt8/test/23435_369576125.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/26232_1378580532.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/30435_1261298563.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/26700_400752214.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/45666_1879230222.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/27344_1661167822.png
# Predicted Y is 0.0 Actual Y is 1.0 File /mnt/wd/CIND860/database/attempt8/test/39920_993630484.png

# %%
def calc_confusion_values(Y,Y_test):
  TP = 0
  TN = 0
  FP = 0
  FN = 0
  n = 0
  for y in Y:
    if Y[n] == 1 and Y_test[n] == 1:
      TP = TP+1
    elif Y[n] == 0 and Y_test[n] == 1:
      FP = FP+1
    elif Y[n] == 0 and Y_test[n] == 0:
      TN = TN+1
    elif Y[n] == 1 and Y_test[n] == 0:
      FN = FN+1
    n = n+1

  cf = np.empty([2,2])
  cf[0,0] = TN
  cf[0,1] = FP
  cf[1,0] = FN
  cf[1,1] = TP
  return(cf)


#        TPR (recall) = TP / P
#        ACC (accuracy) = (TP + TN) / (P + N)
#        PPV (precison) = TP / (TP + FP)
def calc_recall(cf):
  TN, FP, FN, TP=cf.ravel()
  return(TP/(TP+FN))

def calc_precision(cf):
  TN, FP, FN, TP=cf.ravel()
  return(TP/(TP+FP))

def calc_accuracy(cf):
  TN, FP, FN, TP=cf.ravel()
  return((TP+TN)/(TP+FP+TN+FN))

# %%
cf=calc_confusion_values(Y_all, Y_test_all)
TN, FP, FN, TP=cf.ravel()

print("Confusion Matrix:")
print(cf)
print("")
print("TP: ", TP,", FP: ", FP,", TN: ", TN,", FN:", FN)

recall = round(calc_recall(cf),3)
precision = round(calc_precision(cf),3)
accuracy = round(calc_accuracy(cf)*100,3)

print(f"Recall: {recall} Precison: {precision} Accuracy: {accuracy}%")
# Out:
# Confusion Matrix:
# [[196.  19.]
#  [209.  32.]]
#
# TP:  32.0 , FP:  19.0 , TN:  196.0 , FN: 209.0
# Recall: 0.133 Precison: 0.627 Accuracy: 50.0%
